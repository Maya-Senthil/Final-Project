# %% [markdown]
# # Wage or Salary Income in the Past 12 Months...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# load in the data
data = pd.read_csv("community-center-attendance-2019.csv", index_col="Neighborhood", parse_dates=True)

# look at the first ten rows of the data
data.head(10)
