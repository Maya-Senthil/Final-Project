# %% [markdown]
# # Wage or Salary Income in the Past 12 Months...

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Load Dataset get a feel for how it looks

# %%
# load in the data
data = pd.read_csv("wage-or-salary-income-in-the-past-12-months-for-households.csv", index_col="Neighborhood")

# look at the first ten rows of the data
data.head(10)
# Out:
#                    Id  Estimate; Total:  Margin of Error; Total:  \
# Neighborhood
# Allegheny Center    1             870.0                93.000000
# Allegheny West      2             146.0                36.000000
# Allentown           3            1069.0               132.457540
# Arlington           4             701.0               104.465305
# Arlington Heights   5             144.0                59.000000
# Banksville          6            1946.0               229.222599
# Bedford Dwellings   7             723.0                53.000000
# Beechview           8            3567.0               258.027130
# Beltzhoover         9             848.0               156.057682
# Bloomfield         10            4571.0               205.494525
#
#                    Estimate; Total: - With wage or salary income  \
# Neighborhood
# Allegheny Center                                           635.0
# Allegheny West                                             119.0
# Allentown                                                  736.0
# Arlington                                                  570.0
# Arlington Heights                                           99.0
# Banksville                                                1564.0
# Bedford Dwellings                                          348.0
# Beechview                                                 2719.0
# Beltzhoover                                                556.0
# Bloomfield                                                3724.0
#
#                    Margin of Error; Total: - With wage or salary income  \
# Neighborhood
# Allegheny Center                                           91.000000
# Allegheny West                                             35.000000
# Allentown                                                 140.335313
# Arlington                                                 106.273233
# Arlington Heights                                          60.000000
# Banksville                                                216.584856
# Bedford Dwellings                                          71.000000
# Beechview                                                 255.476026
# Beltzhoover                                               128.152253
# Bloomfield                                                206.458228
#
#                    Estimate; Total: - No wage or salary income  \
# Neighborhood
# Allegheny Center                                         235.0
# Allegheny West                                            27.0
# Allentown                                                333.0
# Arlington                                                131.0
# Arlington Heights                                         45.0
# Banksville                                               382.0
# Bedford Dwellings                                        375.0
# Beechview                                                848.0
# Beltzhoover                                              292.0
# Bloomfield                                               847.0
#
#                    Margin of Error; Total: - No wage or salary income
# Neighborhood
# Allegheny Center                                           59.000000
# Allegheny West                                             20.000000
# Allentown                                                  97.493590
# Arlington                                                  45.199558
# Arlington Heights                                          30.000000
# Banksville                                                134.988888
# Bedford Dwellings                                          75.000000
# Beechview                                                 149.207909
# Beltzhoover                                               111.332834
# Bloomfield                                                126.960624

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 91 entries, Allegheny Center to Windgap
# Data columns (total 7 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Id                                                    91 non-null     int64
#  1   Estimate; Total:                                      91 non-null     float64
#  2   Margin of Error; Total:                               91 non-null     float64
#  3   Estimate; Total: - With wage or salary income         91 non-null     float64
#  4   Margin of Error; Total: - With wage or salary income  91 non-null     float64
#  5   Estimate; Total: - No wage or salary income           91 non-null     float64
#  6   Margin of Error; Total: - No wage or salary income    91 non-null     float64
# dtypes: float64(6), int64(1)
# memory usage: 5.7+ KB

# %% [markdown]
# Rename Columns

# %%
data.columns = ['Id', 'Estimate_Total', 'Margin_Error_Total','Estimate_With_Income', 'Margin_Error_With_Income',
                'Estimate_No_Income', 'Margin_Error_No_Income']

# %%
data.head()
# Out:
#                    Id  Estimate_Total  Margin_Error_Total  \
# Neighborhood
# Allegheny Center    1           870.0           93.000000
# Allegheny West      2           146.0           36.000000
# Allentown           3          1069.0          132.457540
# Arlington           4           701.0          104.465305
# Arlington Heights   5           144.0           59.000000
#
#                    Estimate_With_Income  Margin_Error_With_Income  \
# Neighborhood
# Allegheny Center                  635.0                 91.000000
# Allegheny West                    119.0                 35.000000
# Allentown                         736.0                140.335313
# Arlington                         570.0                106.273233
# Arlington Heights                  99.0                 60.000000
#
#                    Estimate_No_Income  Margin_Error_No_Income
# Neighborhood
# Allegheny Center                235.0               59.000000
# Allegheny West                   27.0               20.000000
# Allentown                       333.0               97.493590
# Arlington                       131.0               45.199558
# Arlington Heights                45.0               30.000000

# %%
#make columns

data['Employment_Rate_Percent'] = (data['Estimate_With_Income'] / data['Estimate_Total']) * 100

data['With_Income_Error_Rate'] = (data['Margin_Error_With_Income'] / data['Estimate_With_Income']) * 100

# %%
data.head()
# Out:
#                    Id  Estimate_Total  Margin_Error_Total  \
# Neighborhood
# Allegheny Center    1           870.0           93.000000
# Allegheny West      2           146.0           36.000000
# Allentown           3          1069.0          132.457540
# Arlington           4           701.0          104.465305
# Arlington Heights   5           144.0           59.000000
#
#                    Estimate_With_Income  Margin_Error_With_Income  \
# Neighborhood
# Allegheny Center                  635.0                 91.000000
# Allegheny West                    119.0                 35.000000
# Allentown                         736.0                140.335313
# Arlington                         570.0                106.273233
# Arlington Heights                  99.0                 60.000000
#
#                    Estimate_No_Income  Margin_Error_No_Income  \
# Neighborhood
# Allegheny Center                235.0               59.000000
# Allegheny West                   27.0               20.000000
# Allentown                       333.0               97.493590
# Arlington                       131.0               45.199558
# Arlington Heights                45.0               30.000000
#
#                    Employment_Rate_Percent  With_Income_Error_Rate
# Neighborhood
# Allegheny Center                 72.988506               14.330709
# Allegheny West                   81.506849               29.411765
# Allentown                        68.849392               19.067298
# Arlington                        81.312411               18.644427
# Arlington Heights                68.750000               60.606061

# %% [markdown]
# Show a graph of neighborhoods with 80% or more employment.

# %%
data['is_high_employment'] = data['Employment_Rate_Percent'] > 80

# %%
plt.figure(figsize=(8, 6))
data['is_high_employment'].value_counts().plot(kind='bar')
plt.title('Number of Neighborhoods by Employment Category')
plt.xlabel('High Employment (>80%)')
plt.ylabel('Number of Neighborhoods')
plt.xticks([0, 1], ['False (Low)', 'True (High)'], rotation=0)
plt.show()

# %%
high_employment_df = data[data['is_high_employment'] == True].sort_values('Employment_Rate_Percent', ascending=False)

if high_employment_df.index.name == 'Neighborhood' or any('neighborhood' in str(x).lower() for x in df.index[:3]):
    high_employment_df = high_employment_df.reset_index()
    print("Reset the index - 'Neighborhood' should now be a column")

print("=== HIGH EMPLOYMENT NEIGHBORHOODS ===")
print(f"Total high employment neighborhoods: {len(high_employment_df)}")
print("\nList of High Employment Neighborhoods:")
for idx, row in high_employment_df.iterrows():
    print(f"{row['Neighborhood']}: {row['Employment_Rate_Percent']:.1f}%")
# Out:
# Reset the index - 'Neighborhood' should now be a column
# === HIGH EMPLOYMENT NEIGHBORHOODS ===
# Total high employment neighborhoods: 18
#
# List of High Employment Neighborhoods:
# South Shore: 100.0%
# Fairywood: 100.0%
# North Shore: 95.5%
# Strip District: 92.9%
# Friendship: 91.5%
# Esplen: 86.6%
# Central Oakland: 86.6%
# Summer Hill: 85.5%
# Mt. Oliver: 84.7%
# Perry North: 82.1%
# Shadyside: 82.0%
# West End: 81.8%
# Point Breeze: 81.5%
# Allegheny West: 81.5%
# Bloomfield: 81.5%
# Arlington: 81.3%
# Bluff: 80.4%
# Banksville: 80.4%
